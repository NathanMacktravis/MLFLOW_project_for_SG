# %% [markdown]
# # 1) Compréhensions des notions

# %% [markdown]
# ## a) Compréhension de la noion d'objets ConfigBox

# %%
d = {'key1' : 'val1', 'key2' : 'val2'}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox
d2 = ConfigBox({'key1' : 'val1', 'key2' : 'val2'})

# %%
d2.key1
# Out:
# 'val1'

# %% [markdown]
# # 2) Télécharger des données depuis google Drive

# %%
import gdown

# %%
url_data = "https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"

# %%
# L'id du folder 
file_id = url_data.split("/")[-2]
file_id
# Out:
# '1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3'

# %%
# Téléchargelent du fichier 
 
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=1c263af7-6f0a-4ee6-86c2-f4534be53162
# To: /Users/nathanwandji/Documents/GitHub/MLFLOW_project_for_SG/research/kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:04<00:00, 13.1MB/s]
# 'kidney-CT-Scan-data.zip'
